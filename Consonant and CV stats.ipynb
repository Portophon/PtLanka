# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Packages" data-toc-modified-id="Packages-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Packages</a></span></li><li><span><a href="#Load-data-set" data-toc-modified-id="Load-data-set-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Load data set</a></span></li></ul></li><li><span><a href="#Consonant-Stats" data-toc-modified-id="Consonant-Stats-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Consonant Stats</a></span><ul class="toc-item"><li><span><a href="#Total-consonant-stats" data-toc-modified-id="Total-consonant-stats-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Total consonant stats</a></span></li><li><span><a href="#Words-with-consonant-stats" data-toc-modified-id="Words-with-consonant-stats-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Words with consonant stats</a></span></li><li><span><a href="#Treemap-graphs" data-toc-modified-id="Treemap-graphs-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Treemap graphs</a></span></li></ul></li><li><span><a href="#CV-Stats" data-toc-modified-id="CV-Stats-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>CV Stats</a></span><ul class="toc-item"><li><span><a href="#Total-syllable-stats" data-toc-modified-id="Total-syllable-stats-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Total syllable stats</a></span></li><li><span><a href="#Words-with-syllable-stats" data-toc-modified-id="Words-with-syllable-stats-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Words with syllable stats</a></span></li><li><span><a href="#Treemap-graphs" data-toc-modified-id="Treemap-graphs-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Treemap graphs</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import re
from collections import Counter
import matplotlib.pyplot as plt
import squarify

# %% [markdown]
# ## Load data set

# %%
file_name = "PtLanka.csv"

word_df = pd.read_csv(file_name)
word_df
# Out:
#      SriLanka_creole phonetic_transcription Portuguese_definition   \
# 0              Abaço                  abaso                 abaixo
# 1             Aberçà                abeɾsaː                abraçar
# 2             abersà                abeɾsaː                abraçar
# 3             aburçá                abuɾsaː                abraçar
# 4             Aburcé                abuɾseː              aborrecer
# ...              ...                    ...                    ...
# 2517            Wine                   ʋine          vinho europeu
# 2518           Zumbá                 zumbaː                 zombar
# 2519       Zomberías             zombeɾiːas              zombarias
# 2520        zombrias               zombɾias              zombarias
# 2521       zombàrios             zombaːɾios              zombarias
#
#      English_definition      pos related_languages                   sources   \
# 0                  below  adverb               NaN                        NaN
# 1                    hug    verb               NaN  O Bruffador, ii periódico
# 2                    hug    verb               NaN  O Bruffador, ii periódico
# 3                    hug    verb               NaN  O Bruffador, ii periódico
# 4                  annoy    verb               NaN                        NaN
# ...                  ...     ...               ...                        ...
# 2517       european wine    noun           English                        NaN
# 2518                mock    verb               NaN                        NaN
# 2519             mockery    noun               NaN                        NaN
# 2520             mockery    noun               NaN                        NaN
# 2521             mockery    noun               NaN                        NaN
#
#                                    original_full_entry   \
# 0                              Abaço, abaixo. P. us. V.
# 1              Aberçà, abersà, aburçá {Br. 2), abraçar.
# 2              Aberçà, abersà, aburçá {Br. 2), abraçar.
# 3              Aberçà, abersà, aburçá {Br. 2), abraçar.
# 4                               Aburcé. Mais us. burcé.
# ...                                                 ...
# 2517                                                NaN
# 2518  Zumba, zombar. Zombe-rías, zombrias, zombàrios...
# 2519                                                NaN
# 2520                                                NaN
# 2521                                                NaN
#
#      original_Portuguese_definition  original_linguistic_notes page  \
# 0                             abaixo               pouco usado  135
# 1                            abraçar                       NaN  135
# 2                            abraçar                       NaN  135
# 3                            abraçar                       NaN  135
# 4                    Mesmo que burcé                       NaN  135
# ...                              ...                       ...  ...
# 2517                   vinho europeu                       NaN  NaN
# 2518                          zombar                       NaN  182
# 2519                       zombarias                       NaN  NaN
# 2520                       zombarias                       NaN  NaN
# 2521                       zombarias                       NaN  NaN
#
#      Unnamed: 11  Unnamed: 12
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ...          ...          ...
# 2517         NaN          NaN
# 2518         NaN          NaN
# 2519         NaN          NaN
# 2520         NaN          NaN
# 2521         NaN          NaN
#
# [2522 rows x 13 columns]

# %%
word_list = list(word_df["phonetic_transcription"])
word_list = [" ".join(list(str(i))) for i in word_list]
word_list
# Out:
# ['a b a s o',
#  'a b e ɾ s a ː',
#  'a b e ɾ s a ː',
#  'a b u ɾ s a ː',
#  'a b u ɾ s e ː',
#  'a b l a ː',
#  'a b o ɾ s i d o',
#  'a b s e n s a',
#  'a b s e n t e',
#  'a b u n d a m e n t e',
#  'a b j s o',
#  'a k a ː',
#  'a k s e p t a ː',
#  'a k s e p t a s a ː o',
#  'a k s e p t a ʋ e l',
#  'a k o o m p i ɲ a ː',
#  'a k o ɾ d a ː',
#  'a k o o ɾ d a n s a',
#  'a k o ɾ d a n s e ː',
#  'a s e n t o',
#  'a s e ɾ t o',
#  'a t ̠ ʃ a ɾ',
#  'a s o ɾ a g e',
#  'a d e',
#  'a d e m',
#  'a d e',
#  'a d e ː o',
#  'a d i o ː t o',
#  'a d i ʋ u',
#  'a d i u',
#  'a d i o',
#  'a d e ː o',
#  'a d ̠ ʒ u d a ː',
#  'a d m i ɾ a l',
#  'a d u l t e ː ɾ i a',
#  'a d u l t e ɾ a s a ː o',
#  'a d u l t e ɾ i o z o',
#  'a d u l t e i ɾ o z o',
#  'a d ʋ o k a t',
#  'a d ʋ o g a d o ɾ',
#  'a f a d ̠ ʒ a d o',
#  'a f e s a n',
#  'a f l i k t a ː',
#  'a ː g o ː',
#  'a g o ː ɾ',
#  'a g o r a',
#  'a g o r e ː',
#  'a g ɾ a d a d o',
#  'a g u a ː',
#  'a g u ʋ a ː',
#  'a i n d e ː',
#  'a i o',
#  'a d ̠ ʒ o',
#  'a l a ː',
#  'a l a ː',
#  'a l b ɾ e',
#  'a ː l b ɾ i',
#  'a ː l b i ɾ',
#  'a l d e a n o',
#  'a l d i a',
#  'a l e g ɾ a d o',
#  'a l e g ɾ o z o',
#  'a l e m b ɾ a ː',
#  'a l e m b ɾ a s a ː o',
#  'a l f a d a',
#  'a l f a ː n d a g o',
#  'a l f i a t o',
#  'a l g o z o',
#  'a l g e m s',
#  'a ʎ u m',
#  'a l u m',
#  'a ʎ u m a',
#  'a l g u m   d e   a ʎ u m a s',
#  'a ʎ u m o ɾ a s',
#  'a ʎ u m o ɾ a s   a ʎ u m o ɾ a s  ',
#  'a l a g ɾ a ː',
#  'a l a g ɾ i a ː',
#  'a l a g ɾ e',
#  'a l a g ɾ o z o',
#  'a l e g ɾ i o z o',
#  'a l a g ɾ i a',
#  'a l e g ɾ i',
#  'a l m a ː ɾ i',
#  'a l m a z e m',
#  'a l m o ː s a',
#  'a l k u m a s',
#  'a l t i ʋ i d a d e',
#  'a l u m a d o',
#  'a l u m i n a ː',
#  'a l ʋ e ɾ s a ː o',
#  'a l ʋ o ɾ s a ː',
#  'a l ʋ e ɾ s a ː',
#  'a l ʋ o ɾ o s a ː o',
#  'a l ʋ ɾ o s o',
#  'k a u z e d o ɾ',
#  'd e p a l m i a ː o',
#  'a m a ɲ a ː o',
#  'a m i ɲ a ː o',
#  'a m i a ː o',
#  'a m i a m',
#  'a m a ɾ o z o',
#  'a m e ɾ o z o',
#  'a m o ɾ o',
#  'a m b a l',
#  'a m e ː s a s',
#  'a m i s a n',
#  'a m i z a d e',
#  'a m o s',
#  'a ː m p e ɾ',
#  'a ː m p e ɾ a ː m p e ɾ',
#  'a m p e ː ɾ',
#  'a m p o ɾ t a ː',
#  'a n d a ː',
#  'a n d a ʋ e ː',
#  'a n e l a',
#  'a n i m a',
#  'a n d ̠ ʒ o   t ̠ ʃ u z m o s',
#  'a n d ̠ ʒ o   k u i d a d o ɾ',
#  'a n d ̠ ʒ o   f a l a s',
#  'a n d ̠ ʒ o   ɾ o s t o',
#  'a n d ̠ ʒ o ː l a',
#  'a n k e ɾ a ː',
#  'a n k ɾ a ː',
#  'a n n o   k a z a',
#  'a n n o   d i a',
#  'a n o u t e',
#  'a n s i a d o',
#  'a n s k e',
#  'a n t i f o n o',
#  'a n ʃ i a m e n t e',
#  'a p e ɾ t a m e n t o',
#  'a p a ɾ t a m e n t o',
#  'a p i ɲ a ː',
#  'a p p l i k a s a ː o',
#  'a p p l i k a s a n',
#  'a p p ɾ o ʋ a l',
#  'a p ɾ i l',
#  'a k e ː l',
#  'a k e l e',
#  'a k e l ʋ i d e',
#  'a ɾ k o',
#  'a ː ɾ i a',
#  'a ɾ i a ː',
#  'a ɾ i b a',
#  'a ɾ o m a t i z a ː ɾ s',
#  'a ɾ o s',
#  'a ɾ t a p l e',
#  'a ː ɾ t e i',
#  'a ɾ t i k u l o',
#  'a ɾ t i f i s o',
#  'a ɾ t i ʎ a ː ɾ i s',
#  'a ː s p e ɾ',
#  'a s p e ɾ a ː',
#  'a s p e ɾ d a d e',
#  'a s i',
#  'a s i l a i',
#  'a s i l e i',
#  'a s i t a n t o',
#  'a s t a n t o',
#  'a s i n o',
#  'a s o f ɾ a n',
#  'a s o f ɾ a ː',
#  'a t a ː',
#  'a t a ɾ d e',
#  'a t ̠ ʃ a ː',
#  'a t e ː',
#  'a t ɾ a m e n t o',
#  'a t ɾ a m e n t a ː',
#  'a t ɾ e ʋ i m e n t a ː',
#  'a t ː e ː n s i a',
#  'a t ː e ː n s e ː',
#  'a t ː e ɾ m e z a n',
#  'a u d e ː n s i',
#  'a u d i a',
#  'o ː g o s t',
#  'a ʋ a n t a d ̠ ʒ e m',
#  'a ʋ e ʎ o',
#  'a ʋ e n a ː',
#  'a ʋ o a ː',
#  'a ʋ o g a d o',
#  'a ʋ o ː   m a i',
#  'a ʋ o ː   p a i',
#  'a z e ː t e',
#  'a z i e t e',
#  'a z e i t e ɾ o',
#  'a z i e t e ɾ o',
#  'b a s',
#  'b a ː b a ɾ o',
#  'b e ː b i',
#  'b a k l a ː',
#  'b a k l a d o ɾ',
#  'b a k l a d u ɾ a',
#  'b a k a l d u ɾ a',
#  'b a f a',
#  'b a i l o',
#  'b a i z o',
#  'b a s o',
#  'b a s a ː',
#  'b a s e ː z a',
#  'b a l a n s a',
#  'b a l m a s a d o',
#  'b a l m o',
#  'b e n d',
#  'b a n d a   d e n t ɾ o',
#  'b a n d a   f o ɾ a',
#  'b a n d e ː ɾ e ː',
#  'b a n d e j a',
#  'b a n d ̠ ʒ i a ː',
#  'b a n k',
#  'b e n k ɾ u t',
#  'b a n t s',
#  'b a ɾ i g a',
#  'b a ɾ o',
#  'b a ː ɾ u',
#  'b a ɾ o   k a z a',
#  'b a r a t o',
#  'b a r e ː',
#  'b a ɾ i d o',
#  'b a ː z i n',
#  'b a s o ː ɾ a',
#  'b a s t a n t o',
#  'b a ː t i k a',
#  'b a t ɾ a i',
#  'b a t ː a ː',
#  'b a t ː a ʎ o',
#  'b a t ː e',
#  'b a u t i z m o',
#  'b a u t i z a ː',
#  'b a u t i s t a',
#  'b a i',
#  'b e i',
#  'b a z a ɾ',
#  'b a z a ɾ a',
#  'b e b e ɾ a d ̠ ʒ o',
#  'b e b e ɾ a i',
#  'b e b e ɾ a d ̠ ʒ o t ̠ ʃ a p s',
#  'b e b e ɾ a ː o',
#  'b a b a ɾ a ː o',
#  'b e b ɾ a ː o',
#  'b e b e ɾ a',
#  'b e ː s o',
#  'b i ː a ɾ',
#  'b e m f e i t o',
#  'b e m f e t o',
#  'b e m f e i t o s',
#  'b e n s a',
#  'b e n s e ː',
#  'b e n d i s a ː o',
#  'b e n e f i k a s a n',
#  'b e n i g d a d e',
#  'b e n z e ː',
#  'b e n z a ː',
#  'b e ː n z a',
#  'b e ː n z e ː',
#  'b e ɾ g e ɾ',
#  'b e ɾ j l',
#  'b e ː u d o',
#  'b e u d i s e',
#  'b a i b o l',
#  'b a i b o l   n o m e s',
#  'b i b o ɾ a',
#  'b i d ̠ ʒ a ː',
#  'b i l i a ɾ d',
#  'b i l i a ɾ d   k a ː m b e ɾ',
#  'b i l',
#  'b i z i g a',
#  'b i s p a d a',
#  'b l a d a',
#  'b l a d e ː',
#  'b l a n k e t',
#  'b l a s f e m a s a n',
#  'b l a s f e m o z o',
#  'b o ː a',
#  'b o ː t',
#  'b o b ɾ a',
#  'b o k a d e ː',
#  'b o d ɾ i m o',
#  'b o f e t a d o',
#  'b o f t i a ː',
#  'b u f t i a ː',
#  'b o f t a d a',
#  'b o l t i a ː',
#  'b o m',
#  'b o n a n s e ː',
#  'b o n i n o',
#  'b u t s',
#  'b o ɾ d e ː',
#  'b o ɾ d i a ː',
#  'b o r e s i d o',
#  'b o t a',
#  'b o t l e',
#  'b o t e i',
#  'b o t ː a l',
#  'b o t ː l e   ʋ i ɲ o',
#  'b o u t i k',
#  'b o u t i k e i ɾ o',
#  'b o ʋ e n t a d e',
#  'b o ʋ a n t a d e',
#  'b o ʋ e n t a d e m e n t e',
#  'b o k s',
#  'b ɾ a n k a',
#  'b ɾ a n d a',
#  'b ɾ a n d i',
#  'b ɾ a n k e ː z a',
#  'b ɾ a o',
#  'b ɾ a u',
#  'b ɾ a ʋ i a ː',
#  'b ɾ a z a ː',
#  'b ɾ e m e l i o',
#  'b ɾ i m e l i o',
#  'b ɾ i m a ʎ o',
#  'b ɾ i m e d ̠ ʒ o',
#  'b ɾ i n   k   ə   d e   f o g o',
#  'b u ː ɾ d a ɾ',
#  'b ɾ u f a ː',
#  'b ɾ u f a d o ɾ',
#  'b ɾ u f a m e n t o',
#  'b ɾ u s o',
#  'b u k o',
#  'b u ː k u',
#  'b u n a k a',
#  'b u n i t o',
#  'b u ɾ a ː',
#  'b u ɾ s e ː',
#  'b u ɾ s a ː',
#  'b u ɾ d a d e',
#  'b u ː ɾ u',
#  'b u s k a',
#  'k a b a',
#  'k a ʋ a',
#  'k a b a i',
#  'k a b a j a',
#  'k u o b a i',
#  'k a b e s a',
#  'k a b e s e ː',
#  'k a b e ʎ o',
#  'k a b ɾ a d o',
#  'k a s a ɾ i a',
#  'k a k a d a',
#  'k a t ̠ ʃ o',
#  'k a t ̠ ʃ o ː ɾ',
#  'k a t ̠ ʃ o ɾ i ɲ o',
#  'k a d a o ɾ a',
#  'k a d o ɾ a',
#  'k a d o ɾ',
#  'k a d u m',
#  'k a d e ː',
#  'k a d e ː ɾ a',
#  'k a d i a',
#  'k a f l a ː',
#  'k a f l a s a ː o',
#  'k a f ɾ a n a',
#  'k a i d a s   p e ɾ   t ɾ a s',
#  'k a i ʃ',
#  'k a l a ː o',
#  'k a ː l i s',
#  'k a l m o',
#  'k a l k i ɲ a',
#  'k a l s a ː o',
#  'k a l ʋ a ː ɾ i',
#  'k a m b i a d o ɾ',
#  'k a m b ɾ a',
#  'k a m b ɾ e ː',
#  'k a ː m b e ɾ',
#  'k a m b ɾ a ː o',
#  'k a m ə ɾ a d o',
#  'k a m b ɾ a d o',
#  'k a m p a l',
#  'k a n ə',
#  'k a n d e ː',
#  'k a n a ː ʎ i',
#  'k a n s a ː s',
#  'k a ː n s e ɾ',
#  'k a n d e s e ɾ a',
#  'k a n ə s e ɾ a',
#  'k a n d e l a ː ɾ',
#  'k a n d e l e ː ɾ',
#  'k a ː n d i a',
#  'k a n t o',
#  'k e p',
#  'k a p a s',
#  'k a p i t e l',
#  'k a p t a ː o',
#  'k a p i t a n o',
#  'k a ɾ a ʋ a ː o',
#  'k a ɾ e i ɾ o',
#  'k a ɾ a ɾ o',
#  'k a ɾ g a ː',
#  'k a ɾ g a s a ː o',
#  'k a ɾ i',
#  'k a ɾ i a',
#  'k a ɾ i d a ʋ e l',
#  'k a ɾ i n g e d ̠ ʒ o',
#  'k a ɾ i s t i a',
#  'k a ɾ i s t i',
#  'k a r e s t i a',
#  'k a r e t e',
#  'k a ɾ e t a',
#  'k a ɾ e t e ː',
#  'k a r o',
#  'k a ɾ t a ː',
#  'k a ɾ t a   m e z a',
#  'k a ɾ t e ː',
#  'k a z a   l u g a ː ɾ i a',
#  'k a z a   p o ɾ t a',
#  'k a z i a ː o',
#  'k a s a',
#  'k a s a ː o',
#  'k a s t e l a',
#  'k a s t e l e ː',
#  'k a s t i g a s a ː o',
#  'k a t i ʋ e i ɾ a',
#  'k a t i ʋ i d a d e',
#  'k a t a ː r',
#  'k a u z o',
#  'k a ʋ a d o ɾ',
#  'k a ʋ a ʎ e ɾ i a',
#  'k a ʋ e n t e',
#  'k a ʋ e l ʲ e ː ɾ o',
#  'k a ʋ e l o',
#  'k a ʋ e ɾ n o',
#  'k a ʃ a',
#  's e n d e ː',
#  's e n t o',
#  's e n t a',
#  's e n t s',
#  's e ɾ e m o n i o',
#  's e ɾ t e z a',
#  's e ɾ t e ː z e ː',
#  't ̠ ʃ a b u k o',
#  't ̠ ʃ a b u k a',
#  't ̠ ʃ a l o',
#  't ̠ ʃ a n',
#  't ̠ ʃ a p',
#  't ̠ ʃ a ː p e ː',
#  't ̠ ʃ a p e',
#  't ̠ ʃ a ɾ t',
#  't ̠ ʃ e l a',
#  't ̠ ʃ e ː o',
#  't ̠ ʃ e ː ɾ o',
#  't ̠ ʃ i e ɾ o',
#  't ̠ ʃ i e s t o',
#  't ̠ ʃ i s t o',
#  't ̠ ʃ i s t o',
#  't ̠ ʃ i a d o',
#  't ̠ ʃ e a d i s e',
#  't ̠ ʃ e d i s a',
#  't ̠ ʃ i d i s a',
#  't ̠ ʃ i d i s e',
#  't ̠ ʃ e d i s e   l i n g u a',
#  't ̠ ʃ i n a   p a t a ː s',
#  't ̠ ʃ i n g l a ː',
#  't ̠ ʃ i p i',
#  't ̠ ʃ i t a',
#  't ̠ ʃ o k a r e ː a',
#  't ̠ ʃ o k e ɾ i a',
#  't ̠ ʃ o m a ː',
#  't ̠ ʃ o ː m a',
#  't ̠ ʃ o r a ː',
#  't ̠ ʃ u ɾ a ː',
#  't ̠ ʃ o ː ʋ e',
#  'k ɾ i s t e n d a d e',
#  'k ɾ i s t m a s',
#  't ̠ ʃ u t ̠ ʃ a d a s',
#  't ̠ ʃ u t ̠ ʃ a d o',
#  't ̠ ʃ u l o',
#  't ̠ ʃ u m a ː',
#  't ̠ ʃ u m a s o',
#  't ̠ ʃ u n a m b o',
#  't ̠ ʃ u z m o',
#  's i n k u o',
#  's i n k e ː',
#  's i n k e n t o',
#  's i n t u ɾ a',
#  's i n t u ɾ a ː',
#  's i ɾ k u m s i z a ː',
#  's i ɾ k u m s i a ː',
#  's i ɾ k u m s i d o',
#  's i z o',
#  's i z o m e n t e',
#  'k l a ɾ',
#  'k l a ɾ m e n t e',
#  'k o ː b e ɾ',
#  'k o b i s o',
#  'k o ː f i',
#  'k o j d a ː',
#  'k o j d a d o',
#  's o j t a ː',
#  'k o j t a d o',
#  'k o l e i s a ː o',
#  'k o l o ɾ',
#  'k l o ɾ',
#  'k o l u m n o',
#  'k o ː m a',
#  'k o m e ː',
#  'k o m b e ɾ s a n',
#  'k o m e s a',
#  'k o m e d i',
#  'k o m e ː d e ː',
#  'k o m e ɾ a',
#  'k o m e ː ɾ e ː',
#  'k o m e ɾ o',
#  'k o m e i ɾ a',
#  'k o m e ː ɾ i a',
#  'k o m e ɾ s',
#  'k o m f o ɾ t a b l e',
#  'k o m i d a ː',
#  'k o m i d a s a ː o',
#  'k o m e t ː a ː',
#  'k o m e ː n d a',
#  'k o m i ɲ a ː o',
#  'k o m u n i g a ː',
#  'k o m p a ɲ a',
#  'k o m p i ɲ a',
#  'k o m p a ɲ a ː',
#  'k o m p i ɲ a ː',
#  'k o m p a ɲ a m e n   t o',
#  'k o m p a ɲ i m e n t o',
#  'k o m p i ɲ a m e n t o',
#  'k o m p i ɲ a d o ɾ',
#  'k o m p a ɲ e ː ɾ i o',
#  'k o m p i ɲ e i ɾ o',
#  'k o m p a n i a',
#  'k o m p e t e ː',
#  'k o m p e t a ː',
#  'k o m p l e m e n t o',
#  'k o m p ɾ i d a ː o',
#  'k o m p e ɾ d a ː o',
#  'k o m p ɾ a m e n t o',
#  'k o m t o d o',
#  'k o n ə s e ː',
#  'k o ː n s e ɾ t',
#  'k o n s e ɾ t a ː',
#  'k o n s e ː ɾ t a',
#  'k o n s i a ː',
#  'k o n d i n a ː',
#  'k o n d i n a s a ː o',
#  'k o n f e s a ː o',
#  'k o n f e s o',
#  'k o n f i a d o ɾ',
#  'k o n f i d e n s a',
#  'k o n f i n a',
#  'k o n f o ɾ m a',
#  'k o n f u n d a ː',
#  'k o n f u z a d o',
#  'k o n d u z a d o z o',
#  'k o n s i a n s i a',
#  'k o n s e n s i a',
#  'k o n s e k ɾ a ː',
#  'k o n s e k ɾ a s a ː o',
#  'k o n s e l a ː',
#  'k o n s e l a s a ː o',
#  'k o n s a l a s a ː o',
#  'k o n s e l a d o ɾ',
#  'k o n s e l ʲ o',
#  'k o n s e ʎ a ɾ o',
#  'k o n s e ʎ e ː ɾ o',
#  'k o n s e l e i ɾ o',
#  'k o n s e n t e',
#  'k o n s e k e n s e s',
#  'k o n s i s t a ː',
#  'k o n s t ɾ a n g a ː',
#  'k o n s t ɾ u k t a d o',
#  'k o n s u m a',
#  'k o n t a   p a p e l',
#  'k o n t e n d o',
#  'k o n t e n t a d o',
#  'k o n t e ɾ',
#  'k o n t i n o',
#  'k o n t i n u a l',
#  'k o n t i n u a l m e n t e',
#  'k o n t ɾ a d i z a ː o',
#  'k o n t ɾ a d i z a',
#  'k o n t ɾ a i ɾ o',
#  'k o n t ɾ i a ː',
#  'k o n t ɾ i a s a ː o',
#  'k o n ʋ e ɾ s a ː o',
#  'k o n ʋ e ɾ t a ː',
#  'k o n ʋ e ɾ t a s a ː o',
#  'k o n ʋ i d a s a ː o',
#  'k o n ʋ i n s a ː',
#  'k o p a',
#  'k o p e',
#  'k o p a   t i',
#  'k o p ɾ a',
#  'k o p j',
#  'k o ɾ a d ̠ ʒ e ː',
#  'k o ɾ a d ̠ ʒ o',
#  'k o u ɾ a d ̠ ʒ o',
#  'k o ɾ a d ̠ ʒ e m e n t e',
#  'k o ɾ d a ː',
#  'k o ɾ d i a ː',
#  'k o ɾ d e ː',
#  'k o ɾ e s',
#  'k o ɾ e z m o',
#  'k o ɾ o ʋ a ː',
#  'k o ɾ o ʋ e ː',
#  'k o r e k t a ː',
#  'k o r i g a ː',
#  'k o r e i s a ː o',
#  'k o r e n t e ː',
#  'k u r e n t o',
#  'k o r u p t i d o',
#  'k o ː ɾ t o',
#  'k o ː s e',
#  'k o s i a ː',
#  'k o s e ː ɾ',
#  'k o s t a',
#  'k o u ɾ a s o',
#  'k o ː ɾ t',
#  'k o ː u z u s',
#  'k o u z e ː s',
#  'k o ː ʋ e ɾ',
#  'k o ʋ o d o',
#  'k o ʋ i d o',
#  'k ɾ e d i t o ɾ',
#  'k ɾ e m',
#  'k ɾ e s e n t a ː',
#  'k ɾ i s e n t a ː',
#  'k ɾ i a n s e ː',
#  'k ɾ i e n s a',
#  'k ɾ i m i n a l',
#  'k ɾ i s e ː',
#  'k ɾ i z e ː',
#  'k ɾ u s i f i g a ː',
#  'k ɾ u ʋ e l d a d e',
#  'k u b i s e ː',
#  'k u b i s o',
#  'k u d a',
#  'k u i d a d e',
#  'k u i d a s a ː o',
#  'k u i d a n s a',
#  'k u i d a n s e ː',
#  'k u i d a d o m e n t e',
#  'k u i d a d e m e n t e',
#  'k u d ̠ ʒ e ː ɾ a',
#  'k a l e',
#  'k u ː l i',
#  'k u l p a d o ɾ',
#  'k u m',
#  'k u m a z o',
#  'k u m ə s a ː',
#  'k u p a ː',
#  'k u p a s a ː o',
#  'k u ɾ a ː',
#  'k u ɾ a l',
#  'k u ɾ a ʋ e ː',
#  'k u ɾ t e z i a',
#  'k u z a ː',
#  'k u ː z a',
#  'k u ː s p i',
#  'k o ː s p i',
#  'k u s t u ː m a',
#  'k u s t u m o',
#  'k u s t o m a ː',
#  'd a s e',
#  'd a ː ʎ i',
#  'd a ː l ʲ i',
#  'd a ː i',
#  'd a ː d ̠ ʒ i',
#  'd a ː d i m o',
#  'd a n a ː',
#  'd a n a s a ː o',
#  'd a n a f i k a ː',
#  'd a n a f i k a s a ː o',
#  'd a n d j',
#  'd a ɾ t e ː',
#  'd e ɾ t e ː',
#  'd a ɾ   t o m a ɾ s',
#  'd e s e ː m b e ɾ',
#  'd e   s e o s   ʋ i z i t a d o ɾ',
#  'd e ː',
#  'd e d i a',
#  'd e k',
#  'd e k l a ɾ a ː o',
#  'd e f e ː n s i a',
#  'd e f e n s e ː',
#  'd e i d o',
#  'd e i ʃ a',
#  'd e s a',
#  'd e m o ː n i',
#  'd e ɲ e i ɾ o',
#  'd e ː n t o ɾ',
#  'd e n t ɾ o   ʋ o s',
#  'd e o s   b e ː n z a',
#  'd e ː ɾ',
#  'd e ɾ e m a ː',
#  'd e z a s p a ɾ a ː',
#  'd e s k a ɾ g a ː',
#  'd e s i',
#  'd e s k l o ɾ a ː',
#  'd e s k o m p e t i d o',
#  'd e s k o m p e t i d o m e n t e',
#  'd e s k o n t e n t a d o',
#  'd e s k u i d a s a ː o',
#  'd e s k u i d a n s e ː',
#  'd e z e i d ̠ ʒ o',
#  'd e z e ʎ o',
#  'd e z e i d ̠ ʒ a ː',
#  'd e z e m b a ɾ s a n',
#  'd e z e m p a ː ɾ',
#  'd e z e m p ə ɾ a s a ː o',
#  'd e z e m p a ɾ a ː',
#  'd e z e m p ɾ a ː',
#  'd e s f a m a ː',
#  'd e s f a z e d o',
#  'd e s f a z i d o',
#  'd e s f ɾ u i t o z o',
#  'd e z g a ɾ d e s e ː',
#  'd e z g ɾ a d e s i m e n t o',
#  'd e z g o s t o   ʋ i d a',
#  'd e ʃ o n e s t a d e',
#  'd e z i a ː',
#  'd i z i a ː',
#  'd i z i a ː',
#  'd e z i o',
#  'd i z i o',
#  'd e z i m p o ɾ t a ː',
#  'd e z e m p o ɾ t a ː',
#  'd e z e m p o ɾ t a d o',
#  'd e z e m p o ɾ t a n s a',
#  'd e z e m p o ɾ t a s a ː o',
#  'd e z l i m p o',
#  'd e z l i m p e ː z a',
#  'd e z l i m p a ː',
#  'd e z m a ɾ a ː',
#  'd e z m a z i a s a ː o',
#  'd e z o b e d e n s i a',
#  'd e s p a d a s a ː',
#  'd e s p a ɾ a n s a',
#  'd e s p a ɾ e s e ː',
#  'd e s p a ɾ s e ː',
#  'd i s p a ɾ s i d o',
#  'd e s p o ː d e',
#  'd e s p o j s',
#  'd e s p o s e s a ː',
#  'd e s p ɾ a z a ː',
#  'd e s p ɾ e n d i d o',
#  'd e s p ɾ o ʋ a ː',
#  'd e s p ɾ o ʋ e i t o z o',
#  'd e s t ɾ i b u a ː',
#  'd e s t ɾ i b u a s a ː o',
#  'd e s t ɾ i b u s a ː o',
#  'd e s t ɾ u ʋ e ː',
#  'd e s t ɾ u i ʋ e ː',
#  'd e s t ɾ u ʋ a ː',
#  'd e s t ɾ u i a s a ː o',
#  'd e s t ɾ u i ʋ i s a ː o',
#  'd e s t ɾ u k s a ː o',
#  'd e s ʋ a i',
#  'd e s ʋ a l o z o',
#  'd e t ː a ː',
#  'd e ʋ i d a',
#  'd e ː u d a',
#  'd i e u d e ː',
#  'd e ʋ i d o ɾ',
#  'd i ʋ i d o ɾ',
#  'd e ʋ o t a d o',
#  'd e ʋ o t a m o s',
#  'd e ː z i m o',
#  'd e ː z i m o s',
#  'd e z i m a ː',
#  'd e z   m i l   m i l',
#  'd e z o j t e ː',
#  'd i a',
#  'd i a b o l e i',
#  'd i a m a n t e   d ̠ ʒ u b l i',
#  'd i a n t a ː',
#  'd i a n t e   k a z a',
#  'd i f e ɾ e ː n s i a',
#  'd i ɲ e ː ɾ o',
#  'd i ɾ e k t a ː',
#  'd i z a k o ɾ d a n s e ː',
#  'd e z a p p ɾ o ʋ a d o',
#  'd i s e ː',
#  'd i s e n d e ː',
#  'd i s e ɾ t o',
#  'd i s e t e',
#  'd i s i p l o',
#  'd i s k o n f i a d o ɾ',
#  'd i s k o n f i a d e i ɾ a',
#  'd i s k o n s a l a d o',
#  'd i s k o n t e n t o m e n t o',
#  'd i s k o n ʋ e ɾ t i d o',
#  'd i s k o u ɾ t e z i a',
#  'd i z e m p e ɾ a d o',
#  'd i s f a j e s a ː o',
#  'd i s f i e l',
#  'd i s f i e l d a d o',
#  'd i s f i e l m e n t e',
#  'd i s f i e l d a d e',
#  'd i z d ̠ ʒ e ɾ a d o',
#  'd i z g o s t o',
#  'd i ʃ',
#  'd i ʃ o n o ɾ a ː',
#  'd i ʃ o n ɾ a ː ʋ e l',
#  'd i z l e ʋ e d a d o',
#  'd i z m e ɾ s e ː',
#  'd i z m e ɾ s i m e n t o',
#  'd i z m i s a ː o',
#  'd i z m u e ː',
#  'd e z o b d e s i m e n t o',
#  'd i z o b e d e s i d o',
#  'd i s p e ɾ d i s a ː',
#  'd i s p i d e ː',
#  'd i s p o ː s',
#  'd i s p ɾ a z e i ɾ o',
#  'd i s p u t a s a ː o',
#  'd i z ɾ e g u l a d o',
#  'd i z ɾ e p a ɾ t i d o',
#  'd i z ɾ e z o a d o',
#  'd i s i l i m',
#  'd i s a u d e',
#  'd i s t ɾ a n s a ː',
#  'd i s t ɾ a n s a d o ɾ',
#  'd i s t ɾ a n s o',
#  'd i s t ɾ e s o',
#  'd i s ʋ a l i a',
#  'd i s ʋ a l i a ː',
#  'd i s ʋ a l i o z o',
#  'd i t o',
#  'd i ʋ i n i d a d e',
#  'd i ʋ u d o',
#  'd i z i d o',
#  'd o s e ː ɾ o',
#  'd o ː k t o ɾ',
#  'd o ː d o',
#  'd o d i s e',
#  'd o u d i s a',
#  'd o d i s o',
#  'd o d a d o',
#  'd o e n s a ː',
#  'd o l o ː ɾ',
#  'd o m i n i a ː o',
#  'd o ɾ   k e b ɾ a d o',
#  'd o ː s',
#  'd o u s',
#  'd o u s   d o b ɾ a d o',
#  'd o u t ɾ i n o',
#  'd o u t ɾ o',
#  'd o ʋ e n s e ː',
#  'd o ː   ʋ e s t i d o',
#  'd o z e i ɾ o',
#  'd o u z e i ɾ o',
#  'd o ː z i m o',
#  'd ɾ e k',
#  'd ɾ e ː k e ɾ',
#  'd ɾ e i t o',
#  'd ɾ e t o',
#  'd ɾ o m i',
#  'd ɾ o m e ː',
#  'd ɾ u m e ː',
#  'd ɾ o m i s a ː',
#  'd ɾ o m i s a ː',
#  'd ɾ o p',
#  'd u ː k a t s',
#  'd u ː k i',
#  'd u k e z e ː',
#  'd u ɾ a n s a',
#  'd u ʋ i d a d e',
#  'd u ʋ i d a n s a',
#  'd u ʋ i d a n d o',
#  'e a ɾ n e s t e ː',
#  'e a m e s t e m e n t e',
#  'e a ɾ n e s t i d a d e',
#  'e g u a l a s a ː o',
#  'e g u a l a d o',
#  'e g u a l a d o m e n t e',
#  'e m e n t a ː',
#  'e m e n d a d o ɾ',
#  'e m p e ɾ a d o ɾ',
#  'e m p e ɾ d o ɾ',
#  'e m p ɾ e s a d o',
#  'e n s e n s o',
#  'e n s i ɾ k a ː',
#  'e n k o n t ɾ a s a ː o',
#  'e n k u l k a ː',
#  'e n k u l k a s a ː o',
#  'e n f a n t e',
#  'e n f e ɾ n o',
#  'e n d ̠ ʒ e i t a ː',
#  'e n g l a n t e r a',
#  'e n g ɾ a t o',
#  'e n g e n t o',
#  'e n i m i g o',
#  'e n i m i n g o',
#  'e n e m i n g o',
#  'e n d ̠ ʒ o e ʎ o',
#  'e n d ̠ ʒ o e ʎ a ː',
#  'e n d ̠ ʒ u s t i s i a',
#  'e n l u m i n a ː',
#  'e n l u m i a ː',
#  'e n ɾ o d i a ː',
#  'e n s i n a d o ɾ',
#  'e n s o m b ɾ a d o',
#  'e n t e i ɾ o',
#  'e n t e ː n s i a',
#  'e n ʋ e ː d ̠ ʒ a',
#  'e n ʋ e d ̠ ʒ e ː',
#  'e n ʋ e ː d ̠ ʒ o',
#  'e n ʋ e i d ̠ ʒ o',
#  'e n ʋ i s t e ː',
#  'e ɾ d a ː ʋ e ː',
#  'e ɾ d e ː ɾ o',
#  'e ɾ o p a',
#  'e s k o l a   m e s t ɾ e',
#  'e s f ɾ i a d o',
#  'e s p e ɾ d i s a ː',
#  'e s p e ɾ d i s e ː',
#  'e s p e ɾ d e s a ː',
#  'e s p e ɾ d e s e ː',
#  'e s p e ɾ d i s a ː o',
#  'e s p e ɾ t a',
#  'e s p e ɾ t e l',
#  'e s t e',
#  'e s t e l e i',
#  'e s t o p o',
#  'e t i k u a',
#  'f a ː b ɾ e',
#  'f a s a',
#  'f a e ː',
#  'f a l a ː',
#  'f a l a ɾ s',
#  'f a l s e n t o',
#  'f a l s o d a d e',
#  'f a l t a n s a',
#  'f a m a d o',
#  'f a ː m e a',
#  'f a m i ʎ a',
#  'f a m i l ʲ e ː',
#  'f a m i ʎ a   o ɾ a s a ː o',
#  'f a m i ʎ a d o',
#  'f a s',
#  'f e ː ʃ o n',
#  'f a ʋ o ɾ a ː',
#  'f a ʋ o ɾ a d o',
#  'f a ʋ o ɾ o z o',
#  'f a ʋ o ɾ o z o m e n t e',
#  'f a ʋ o u ɾ',
#  'f a ː z e',
#  'f a z e d o',
#  'f a z i d o',
#  'f a z e n d o',
#  'f e ː b ɾ u a ɾ i',
#  'f e e',
#  'f e i r e ː ɾ o',
#  'f e l i z a m e n t e',
#  'f e l i z i d a d e',
#  'f e m e ː',
#  'f e ː o',
#  'f e u',
#  'f e u d a d e',
#  'f e ɾ a ː o',
#  'f e ɾ i d o',
#  'f e ɾ o',
#  'f e r a ɾ o',
#  'f e s a ː o',
#  'f e s t e ː',
#  'f e s t i a ː',
#  'f e t i s e ɾ i a',
#  'f e t i s o',
#  'f e t i s e ː ɾ o',
#  'f e t o',
#  'f i a d o',
#  'f i a l',
#  'f i k a ː',
#  'f i t ̠ ʃ a ː',
#  'f i k t i s i o z o',
#  'f i e l d a d e',
#  'f i f e s f i f i e s',
#  'f e ː f e s',
#  'f i f e i s',
#  'f i f i',
#  'f i g a s',
#  'f i g o',
#  'f i ʎ o   d e   m o s a',
#  'f i l ʲ o',
#  'f i ɾ m e m e n t o',
#  'f i ɾ m i d a d e',
#  'f i z g a ː',
#  'f i t ̠ ʃ a ː',
#  'f i t e ː',
#  'f l a m a',
#  'f l a u',
#  'f l e k',
#  'f l o ɾ i s e ː',
#  'f l o ɾ i s e m e n t o',
#  'f o g a ː',
#  'f o ː l g a',
#  'f o l g a s a ː o',
#  'f o ʎ o',
#  'f o l m a k',
#  'f o m e',
#  'f o n t e   k ɾ j s t a l',
#  'f o n t e n a',
#  'f o ɾ s a',
#  'f o ɾ s e ː',
#  'f o ɾ s a m e n t e',
#  'f o ɾ s a d o m e n t e',
#  'f o ɾ d e ː',
#  ...]

# %% [markdown]
# # Consonant Stats

# %%
word_list = [re.sub("(?<=[aeiout]) ː", "ː", i) for i in word_list]
word_list = [re.sub("(?<=[nl]) ʲ", "ʲ", i) for i in word_list]
word_list = [re.sub("d ̠ ʒ", "d̠ʒ", i) for i in word_list]
word_list = [re.sub("t ̠ ʃ", "t̠ʃ", i) for i in word_list]
word_list = [re.sub("^", " ", i) for i in word_list]
word_list = [re.sub("$", " ", i) for i in word_list]

word_list[0:10]
# Out:
# [' a b a s o ',
#  ' a b e ɾ s aː ',
#  ' a b e ɾ s aː ',
#  ' a b u ɾ s aː ',
#  ' a b u ɾ s eː ',
#  ' a b l aː ',
#  ' a b o ɾ s i d o ',
#  ' a b s e n s a ',
#  ' a b s e n t e ',
#  ' a b u n d a m e n t e ']

# %%
word_list_split = [i.split(" ") for i in word_list]
word_list_split = [item for sublist in word_list_split for item in sublist]
word_list_split = [x for x in word_list_split if x]
vowel_punct = ["a","aː","e","eː","i","iː","o","oː","u","uː","ə","-"]
word_list_split = [e for e in word_list_split if e not in vowel_punct]

# %% [markdown]
# ## Total consonant stats

# %%
counts = Counter(word_list_split)
df = pd.DataFrame.from_dict(counts, orient='index').reset_index()
df.columns = ["IPA", "count"]
df = df.sort_values(by=["count"],ascending=False).reset_index(drop=True)
df
# Out:
#     IPA  count
# 0     ɾ   1273
# 1     s   1055
# 2     d    905
# 3     n    874
# 4     t    847
# 5     m    679
# 6     p    557
# 7     k    530
# 8     l    461
# 9     ʋ    310
# 10    b    308
# 11    z    305
# 12    f    246
# 13    g    224
# 14    r    160
# 15  d̠ʒ    158
# 16  t̠ʃ     69
# 17    ɲ     54
# 18    j     43
# 19    ʎ     42
# 20   tː     16
# 21    ʃ     15
# 22   lʲ     13
# 23   nʲ      2

# %% [markdown]
# ## Words with consonant stats

# %%
IPA_list = list(df["IPA"])
in_word_list = []
for word in IPA_list:
    word_search = " "+ word + " "
    matches = len([match for match in word_list if word_search in match])
    in_word_list.append(matches)
df["word_count"] = in_word_list
df["IPA_count_label"] = df["IPA"] + " : " + df["count"].astype(str)
df["IPA_word_count_label"] = df["IPA"] + " : " + df["word_count"].astype(str)
df
# Out:
#     IPA  count  word_count IPA_count_label IPA_word_count_label
# 0     ɾ   1273        1160        ɾ : 1273             ɾ : 1160
# 1     s   1055         938        s : 1055              s : 938
# 2     d    905         772         d : 905              d : 772
# 3     n    874         780         n : 874              n : 780
# 4     t    847         777         t : 847              t : 777
# 5     m    679         639         m : 679              m : 639
# 6     p    557         519         p : 557              p : 519
# 7     k    530         517         k : 530              k : 517
# 8     l    461         458         l : 461              l : 458
# 9     ʋ    310         307         ʋ : 310              ʋ : 307
# 10    b    308         294         b : 308              b : 294
# 11    z    305         298         z : 305              z : 298
# 12    f    246         238         f : 246              f : 238
# 13    g    224         220         g : 224              g : 220
# 14    r    160         160         r : 160              r : 160
# 15  d̠ʒ    158         152       d̠ʒ : 158            d̠ʒ : 152
# 16  t̠ʃ     69          67        t̠ʃ : 69             t̠ʃ : 67
# 17    ɲ     54          54          ɲ : 54               ɲ : 54
# 18    j     43          43          j : 43               j : 43
# 19    ʎ     42          41          ʎ : 42               ʎ : 41
# 20   tː     16          16         tː : 16              tː : 16
# 21    ʃ     15          15          ʃ : 15               ʃ : 15
# 22   lʲ     13          13         lʲ : 13              lʲ : 13
# 23   nʲ      2           2          nʲ : 2               nʲ : 2

# %% [markdown]
# ## Treemap graphs

# %%
labels = list(df["IPA_count_label"])
sizes = list(df["count"])
squarify.plot(sizes, label = labels, alpha=0.6, pad=True)
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 16)
plt.axis('off')
plt.show()

# %%
labels = list(df["IPA_word_count_label"])
sizes = list(df["count"])
squarify.plot(sizes, label = labels, alpha=0.6, pad=True)
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 16)
plt.axis('off')
plt.show()

# %% [markdown]
# # CV Stats

# %% [markdown]
# ## Load dataset

# %%
file_name = "crioulo_IPA_CV.csv"

word_df = pd.read_csv(file_name)
word_df
# Out:
#      SriLanka_creole phonetic_transcription   phono_TRSVD      phono_CV
# 0              Abaço                  abaso       V.TV.SV       V.CV.CV
# 1             Aberçà                abeɾsaː      V.TVR.SV      V.CVC.CV
# 2             abersà                abeɾsaː      V.TVR.SV      V.CVC.CV
# 3             aburçá                abuɾsaː      V.TVR.SV      V.CVC.CV
# 4             Aburcé                abuɾseː      V.TVR.SV      V.CVC.CV
# ...              ...                    ...           ...           ...
# 2517            Wine                   ʋine         TV.RV         CV.CV
# 2518           Zumbá                 zumbaː        TVR.TV        CVC.CV
# 2519       Zomberías             zombeɾiːas  TVR.TV.RV.VS  CVC.CV.CV.VC
# 2520        zombrias               zombɾias    TVR.TRV.VS    CVC.CCV.VC
# 2521       zombàrios             zombaːɾios  TVR.TV.RV.VS  CVC.CV.CV.VC
#
# [2522 rows x 4 columns]

# %%
word_list_CV = list(word_df["phono_CV"])
word_list_split = [i.split(".") for i in word_list_CV]
word_list_split = [item for sublist in word_list_split for item in sublist]
word_list_split = [i.split(" ") for i in word_list_split]
word_list_split = [item for sublist in word_list_split for item in sublist]
word_list_split[:] = [x for x in word_list_split if x]

# %% [markdown]
# ## Total syllable stats

# %%
counts = Counter(word_list_split)
df = pd.DataFrame.from_dict(counts, orient='index').reset_index()
df.columns = ["CV", "count"]
df = df.sort_values(by=["count"],ascending=False).reset_index(drop=True)
df
# Out:
#        CV  count
# 0      CV   4461
# 1     CVC   1345
# 2       V    733
# 3     CCV    425
# 4      VC    219
# 5     CVV    123
# 6       C    119
# 7    CCVC    102
# 8    CVCV     82
# 9      VV     21
# 10     CC     18
# 11   CCVV     16
# 12  CVCVC     15
# 13   CVVC     15
# 14   CVCC     13
# 15    VCC      5
# 16  CCVCC      4
# 17  CCVVC      2

# %% [markdown]
# ## Words with syllable stats

# %%
word_list_CV = [re.sub("\.", " ", i) for i in word_list_CV]
word_list_CV = [re.sub("^", " ", i) for i in word_list_CV]
word_list_CV = [re.sub("$", " ", i) for i in word_list_CV]

# %%
CV_list = list(df["CV"])
in_word_list = []
for word in CV_list:
    word_search = " "+ word + " "
    matches = len([match for match in word_list_CV if word_search in match])
    in_word_list.append(matches)
df["word_count"] = in_word_list
df["word_count"] = in_word_list
df["CV_count_label"] = df["CV"] + " : " + df["count"].astype(str)
df["CV_word_count_label"] = df["CV"] + " : " + df["word_count"].astype(str)
df
# Out:
#        CV  count  word_count CV_count_label CV_word_count_label
# 0      CV   4461        2288      CV : 4461           CV : 2288
# 1     CVC   1345        1130     CVC : 1345          CVC : 1130
# 2       V    733         661        V : 733             V : 661
# 3     CCV    425         419      CCV : 425           CCV : 419
# 4      VC    219         217       VC : 219            VC : 217
# 5     CVV    123         121      CVV : 123           CVV : 121
# 6       C    119         113        C : 119             C : 113
# 7    CCVC    102         101     CCVC : 102          CCVC : 101
# 8    CVCV     82          81      CVCV : 82           CVCV : 81
# 9      VV     21          21        VV : 21             VV : 21
# 10     CC     18          17        CC : 18             CC : 17
# 11   CCVV     16          16      CCVV : 16           CCVV : 16
# 12  CVCVC     15          15     CVCVC : 15          CVCVC : 15
# 13   CVVC     15          15      CVVC : 15           CVVC : 15
# 14   CVCC     13          13      CVCC : 13           CVCC : 13
# 15    VCC      5           5        VCC : 5             VCC : 5
# 16  CCVCC      4           4      CCVCC : 4           CCVCC : 4
# 17  CCVVC      2           2      CCVVC : 2           CCVVC : 2

# %% [markdown]
# ## Treemap graphs

# %%
labels = list(df["CV_count_label"])
sizes = list(df["count"])
squarify.plot(sizes, label = labels, alpha=0.6, pad=True)
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 16)
plt.axis('off')
plt.show()

# %%
labels = list(df["CV_word_count_label"])
sizes = list(df["count"])
squarify.plot(sizes, label = labels, alpha=0.6, pad=True)
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 16)
plt.axis('off')
plt.show()

# %%
word_df[word_df['phono_CV'].str.contains("CCVCC")]
# Out:
#      SriLanka_creole phonetic_transcription      phono_TRSVD         phono_CV
# 1397         Maslins                mazlins         RV.TRVRS         CV.CCVCC
# 1923         Prinspo                pɾinspo         TRVRS.TV         CCVCC.CV
# 1924         prenspo                pɾenspo         TRVRS.TV         CCVCC.CV
# 2346    Transportado           tɾanspoɾtado  TRVRS.TVR.TV.TV  CCVCC.CVC.CV.CV
